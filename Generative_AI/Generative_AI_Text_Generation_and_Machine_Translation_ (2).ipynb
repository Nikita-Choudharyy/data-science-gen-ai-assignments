# %% [markdown]
# #Generative AI - Text Generation and Machine Translation

# %% [markdown]
# # Question 1: What is Generative AI and what are its primary use cases across industries?
#
#
# **Generative AI (Artificial Intelligence)** is a branch of Artificial Intelligence that enables machines to **create new content** such as text, images, audio, videos, computer code, and other forms of data. Unlike traditional AI, which mainly focuses on analyzing or classifying existing data, Generative AI learns patterns from large datasets and generates new content that resembles the data it was trained on.
#
# Generative AI is powered by advanced deep learning models such as **Large Language Models (LLMs)**, **Generative Adversarial Networks (GANs)**, **Variational Autoencoders (VAEs)**, and **Transformer-based models**. These models can understand context, recognize patterns, and produce high-quality outputs based on user prompts.
#
#
# # Primary Use Cases Across Industries
#
# ## 1. Healthcare
#
# Generative AI helps improve healthcare by assisting medical professionals in diagnosis, research, and documentation.
#
# ### Applications
#
# - Medical report generation
# - Drug discovery
# - Disease prediction
# - Medical image analysis
# - Clinical documentation
#
#
# ## 2. Education
#
# Generative AI enhances learning by creating personalized educational content.
#
# ### Applications
#
# - AI tutors
# - Automatic question generation
# - Assignment assistance
# - Language learning
# - Personalized learning materials
#
#
#
# ## 3. Banking and Finance
#
# Financial institutions use Generative AI to improve customer service and automate business processes.
#
# ### Applications
#
# - Fraud detection support
# - Customer service chatbots
# - Financial report generation
# - Risk analysis
# - Loan assistance
#
#
#
# ## 4. Software Development
#
# Developers use Generative AI to write, review, and optimize code.
#
# ### Applications
#
# - Code generation
# - Code completion
# - Bug detection
# - Code documentation
# - Software testing assistance
#
#
#
# ## 5. Marketing and Advertising
#
# Generative AI helps businesses create engaging marketing content.
#
# ### Applications
#
# - Advertisement creation
# - Social media content generation
# - Email writing
# - Product descriptions
# - Content marketing
#
#
#
# ## 6. Entertainment and Media
#
# Generative AI is widely used to create creative digital content.
#
# ### Applications
#
# - Story writing
# - Music generation
# - Video generation
# - Image creation
# - Script writing
#
#
#
# ## 7. Customer Support
#
# Organizations use AI-powered chatbots and virtual assistants to improve customer experience.
#
# ### Applications
#
# - 24/7 customer support
# - Automated responses
# - Query resolution
# - Virtual assistants
# - FAQ generation
#
#
#
# ## 8. Manufacturing
#
# Generative AI improves industrial productivity and operational efficiency.

# %% [markdown]
# # Question 2: Explain the role of probabilistic modeling in generative models. How do these models differ from discriminative models?
#
#
# # Role of Probabilistic Modeling in Generative Models
#
# Probabilistic modeling plays several important roles in generative models:
#
# ### 1. Learns Data Distribution
#
# It learns how the training data is distributed, allowing the model to understand patterns and relationships between features.
#
#
#
# ### 2. Generates New Data
#
# Once the probability distribution is learned, the model can generate new text, images, audio, or other data that closely resembles the training data.
#
#
# ### 3. Handles Uncertainty
#
# Real-world data often contains uncertainty and variation. Probabilistic models account for this uncertainty, making the generated outputs more realistic.
#
#
#
# ### 4. Improves Sampling
#
# By sampling from the learned probability distribution, the model can create diverse and meaningful outputs instead of producing identical results every time.
#
#
#
# ### 5. Supports Missing Data Estimation
#
# Probabilistic models can estimate missing or incomplete information based on the learned distribution, making them useful for data completion tasks.
#
#
#
# # Difference Between Generative and Discriminative Models
#
# | Feature | Generative Models | Discriminative Models |
# |---------|-------------------|-----------------------|
# | **Purpose** | Generate new data and model how data is created. | Classify or predict labels for existing data. |
# | **Probability Learned** | Learns the **joint probability distribution** of data. | Learns the **conditional probability** of labels given the input. |
# | **Output** | Generates new samples such as text, images, or audio. | Predicts class labels or numerical values. |
# | **Main Objective** | Understand and reproduce the data distribution. | Separate or classify different classes accurately. |
# | **Examples** | GAN, VAE, GPT | Logistic Regression, SVM, Random Forest |

# %% [markdown]
# # Question 3: What is the difference between Autoencoders and Variational Autoencoders (VAEs) in the context of text generation?
# -
#
# # Autoencoder
#
# An **Autoencoder (AE)** is a neural network that learns to compress input data into a smaller representation called the **latent vector** and then reconstruct the original input from this representation.
#
# ### Architecture of an Autoencoder
#
# 1. **Encoder**
#    - Compresses the input text into a low-dimensional latent representation.
#
# 2. **Latent Space**
#    - Stores the compressed representation of the input.
#
# 3. **Decoder**
#    - Reconstructs the original text from the latent representation.
#
# ### Role in Text Generation
#
# - Learns useful text features.
# - Mainly reconstructs existing text.
# - Does not generate diverse or completely new text effectively.
#
#
#
# #  Variational Autoencoder (VAE)
#
# A **Variational Autoencoder (VAE)** is an extension of the Autoencoder that learns a **probability distribution** over the latent space instead of a single fixed latent vector.
#
# Instead of encoding each input into one point, a VAE encodes it as a **distribution (mean and variance)**. During generation, new latent vectors are sampled from this distribution and passed to the decoder to generate new text.
#
# ### Architecture of a VAE
#
# 1. **Encoder**
#    - Learns the mean and variance of the latent distribution.
#
# 2. **Latent Distribution**
#    - Represents the data as a probability distribution rather than a fixed vector.
#
# 3. **Sampling Layer**
#    - Randomly samples latent vectors from the learned distribution.
#
# 4. **Decoder**
#    - Generates new text from the sampled latent vector.
#
# ### Role in Text Generation
#
# - Generates new and diverse sentences.
# - Produces smoother latent representations.
# - Suitable for creative text generation and language modeling.

# %% [markdown]
# # Question 4: Describe the working of Attention Mechanisms in Neural Machine Translation (NMT). Why are they critical?
#
#
# # Working of the Attention Mechanism
#
# The Attention Mechanism works through the following steps:
#
# ### Step 1: Encode the Input Sentence
#
# The encoder processes each word in the source sentence and generates a sequence of hidden states. Each hidden state contains information about a particular word and its surrounding context.
#
#
#
# ### Step 2: Calculate Attention Scores
#
# When generating each word in the translated sentence, the decoder compares its current hidden state with all encoder hidden states.
#
# This comparison produces **attention scores**, which indicate how relevant each source word is to the current target word.
#
#
#
# ### Step 3: Compute Attention Weights
#
# The attention scores are converted into **attention weights** using the **Softmax** function.
#
# These weights represent the importance of each input word, and their values sum to 1.
#
#
#
# ### Step 4: Create the Context Vector
#
# A **context vector** is computed as the weighted sum of all encoder hidden states using the attention weights.
#
# This context vector contains the most relevant information needed to generate the next translated word.
#
#
# ### Step 5: Generate the Output Word
#
# The decoder combines:
#
# - Its current hidden state.
# - The context vector.
#
# Using this information, it predicts the next word in the translated sentence.
#
# The same process is repeated until the complete translated sentence is generated.
#
#
#
# # Why is Attention Critical?
#
# The Attention Mechanism is essential because it addresses several limitations of traditional encoder-decoder models.
#
# ### 1. Handles Long Sentences
#
# Instead of relying on a single fixed-length vector, attention allows the decoder to access all encoder hidden states, improving translations of long sentences.
#
#
#
# ### 2. Improves Translation Accuracy
#
# The model focuses on the most relevant words while translating each target word, leading to more accurate and context-aware translations.
#
#
#
# ### 3. Captures Context Better
#
# Attention helps the model understand relationships between words that are far apart in a sentence.
#
#
#
# ### 4. Reduces Information Loss
#
# Important information from the source sentence is preserved because the decoder can refer back to any part of the input whenever needed.
#
#
#
# ### 5. Forms the Foundation of Modern NLP Models
#
# Attention is the core idea behind **Transformer** architectures, which power modern Large Language Models (LLMs) such as **BERT**, **GPT**, and many advanced machine translation systems.

# %% [markdown]
# # Question 5: What ethical considerations must be addressed when using Generative AI for creative content such as poetry or storytelling?
#
# # Ethical Considerations in Generative AI
#
# ## 1. Copyright and Intellectual Property
#
# Generative AI models are often trained on large datasets that may include copyrighted material. There is a risk that AI-generated content could unintentionally resemble or reproduce protected works.
#
# ### Importance
#
# - Respect copyright laws.
# - Avoid plagiarism.
# - Credit original creators when appropriate.
# - Ensure AI-generated content does not violate intellectual property rights.
#
#
#
# ## 2. Plagiarism and Originality
#
# Creative works generated by AI should be original and should not copy existing poems, stories, or books.
#
# ### Importance
#
# - Encourage creativity.
# - Prevent duplication of existing content.
# - Maintain academic and professional integrity.
#
#
#
# ## 3. Bias and Fairness
#
# If an AI model is trained on biased data, it may generate content containing stereotypes, discrimination, or unfair representations of individuals or communities.
#
# ### Importance
#
# - Reduce harmful bias.
# - Promote fairness and inclusivity.
# - Ensure respectful representation of different cultures and groups.
#
#
#
# ## 4. Misinformation and False Content
#
# Generative AI may create inaccurate or misleading information that appears believable.
#
# ### Importance
#
# - Verify facts before publishing AI-generated content.
# - Prevent the spread of misinformation.
# - Maintain trust and credibility.
#
#
#
# ## 5. Transparency
#
# Readers should know when content has been generated or significantly assisted by AI.
#
# ### Importance
#
# - Build trust with users.
# - Encourage responsible AI use.
# - Clearly disclose AI-generated content when appropriate.
#
#
# ## 6. Privacy and Confidentiality
#
# AI systems should not reveal or misuse personal or confidential information during content generation.
#
# ### Importance
#
# - Protect user privacy.
# - Comply with data protection regulations.
# - Prevent unauthorized disclosure of sensitive information.
#
#
# ## 7. Harmful or Offensive Content
#
# Generative AI should avoid producing content that promotes violence, hate speech, harassment, or discrimination.
#
# ### Importance
#
# - Protect users from harmful material.
# - Promote respectful and responsible communication.
# - Support safe online environments.
#
#
# ## 8. Human Oversight
#
# AI-generated creative content should be reviewed by humans before publication, especially for professional or public use.
#
# ### Importance
#
# - Improve quality and accuracy.
# - Detect errors or inappropriate content.
# - Ensure ethical standards are maintained.

# %% [markdown]
# ###Question 6: Use the following small text dataset to train a simple Variational Autoencoder (VAE) for text reconstruction:
# ["The sky is blue", "The sun is bright", "The grass is green",
# "The night is dark", "The stars are shining"]
# 1. Preprocess the data (tokenize and pad the sequences)
# 2. Build a basic VAE model for text reconstruction
# 3. Train the model and show how it reconstructs or generates similar sentences.

# %%
# Import required libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import backend as K

# ---------------------------------------------------
# Step 1: Dataset
# ---------------------------------------------------

texts = [
    "The sky is blue",
    "The sun is bright",
    "The grass is green",
    "The night is dark",
    "The stars are shining"
]

# ---------------------------------------------------
# Step 2: Text Preprocessing
# ---------------------------------------------------

tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)

max_length = max(len(seq) for seq in sequences)

X = pad_sequences(sequences,
                  maxlen=max_length,
                  padding="post")

vocab_size = len(tokenizer.word_index) + 1

print("Vocabulary Size:", vocab_size)
print("\nPadded Sequences:\n")
print(X)

# ---------------------------------------------------
# Step 3: Build Encoder
# ---------------------------------------------------

embedding_dim = 16
latent_dim = 8

inputs = Input(shape=(max_length,))

x = Embedding(vocab_size,
              embedding_dim)(inputs)

x = LSTM(32)(x)

z_mean = Dense(latent_dim)(x)
z_log_var = Dense(latent_dim)(x)

# Sampling Function
def sampling(args):
    z_mean, z_log_var = args

    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim))

    return z_mean + K.exp(0.5 * z_log_var) * epsilon

z = Lambda(sampling)([z_mean, z_log_var])

# ---------------------------------------------------
# Step 4: Decoder
# ---------------------------------------------------

decoder = Dense(max_length, activation="linear")

outputs = decoder(z)

vae = Model(inputs, outputs)

# ---------------------------------------------------
# Step 5: Compile Model
# ---------------------------------------------------

vae.compile(
    optimizer="adam",
    loss="mse"
)

# ---------------------------------------------------
# Step 6: Train Model
# ---------------------------------------------------

history = vae.fit(
    X,
    X.astype("float32"),
    epochs=100,
    batch_size=2,
    verbose=1
)

# ---------------------------------------------------
# Step 7: Reconstruction
# ---------------------------------------------------

reconstructed = vae.predict(X)

print("\nReconstructed Output:\n")

print(np.round(reconstructed, 2))
# Out:
# Vocabulary Size: 14
#
# Padded Sequences:
#
# [[ 1  3  2  4]
#  [ 1  5  2  6]
#  [ 1  7  2  8]
#  [ 1  9  2 10]
#  [ 1 11 12 13]]
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 40.5470
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 33.2910
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 37.4308
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 43.7603
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 43.0524
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 40.9845
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 38.7595
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 40.1178
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 39.7773
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 43.2714
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 38.2750
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 41.0891
# Epoch 13/100
# ...

# %% [markdown]
# ### Explanation
#
# 1. The text dataset is first tokenized using the Keras **Tokenizer**.
# 2. Each sentence is converted into numerical sequences.
# 3. The sequences are padded to the same length using **pad_sequences()**.
# 4. The encoder converts the input sequence into a latent representation by learning:
#    - Mean (z_mean)
#    - Variance (z_log_var)
# 5. A sampling layer generates a latent vector from this probability distribution.
# 6. The decoder reconstructs the original sequence from the latent vector.
# 7. After training, the model attempts to reconstruct sentences that are similar to the original inputs.

# %% [markdown]
# ###Question 7: Use a pre-trained GPT model (like GPT-2 or GPT-3) to translate a short English paragraph into French and German. Provide the original and translated text.

# %%
# Install libraries (Run once)
# !pip install -q transformers sentencepiece torch accelerate

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load FLAN-T5 model
model_name = "google/flan-t5-base"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Original text
text = """
Artificial Intelligence is transforming the world by helping people solve
complex problems. It improves healthcare, education, finance, and many
other industries through automation and intelligent decision-making.
"""

print("="*60)
print("Original English Text")
print("="*60)
print(text)

# ---------------- French ----------------

prompt = "Translate the following English text to French:\n" + text

inputs = tokenizer(prompt, return_tensors="pt")

outputs = model.generate(**inputs, max_new_tokens=200)

french = tokenizer.decode(outputs[0], skip_special_tokens=True)

# ---------------- German ----------------

prompt = "Translate the following English text to German:\n" + text

inputs = tokenizer(prompt, return_tensors="pt")

outputs = model.generate(**inputs, max_new_tokens=200)

german = tokenizer.decode(outputs[0], skip_special_tokens=True)

# ---------------- Output ----------------

print("\n" + "="*60)
print("French Translation")
print("="*60)
print(french)

print("\n" + "="*60)
print("German Translation")
print("="*60)
print(german)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:124: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ###Question 8: Implement a simple attention-based encoder-decoder model for English-to-Spanish translation using Tensorflow or PyTorch.

# %%
# Import required libraries
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Attention, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# ----------------------------------------------------
# Sample Dataset
# ----------------------------------------------------

english_sentences = [
    "hello",
    "how are you",
    "good morning",
    "thank you",
    "i love you"
]

spanish_sentences = [
    "hola",
    "como estas",
    "buenos dias",
    "gracias",
    "te amo"
]

# ----------------------------------------------------
# Tokenization
# ----------------------------------------------------

eng_tokenizer = Tokenizer()
eng_tokenizer.fit_on_texts(english_sentences)

spa_tokenizer = Tokenizer()
spa_tokenizer.fit_on_texts(spanish_sentences)

encoder_input = eng_tokenizer.texts_to_sequences(english_sentences)
decoder_output = spa_tokenizer.texts_to_sequences(spanish_sentences)

max_eng_len = max(len(seq) for seq in encoder_input)
max_spa_len = max(len(seq) for seq in decoder_output)

encoder_input = pad_sequences(
    encoder_input,
    maxlen=max_eng_len,
    padding="post"
)

decoder_output = pad_sequences(
    decoder_output,
    maxlen=max_spa_len,
    padding="post"
)

# ----------------------------------------------------
# Build Encoder
# ----------------------------------------------------

embedding_dim = 32
lstm_units = 64

encoder_inputs = Input(shape=(max_eng_len,))

encoder_embedding = Embedding(
    input_dim=len(eng_tokenizer.word_index) + 1,
    output_dim=embedding_dim
)(encoder_inputs)

encoder_outputs, state_h, state_c = LSTM(
    lstm_units,
    return_sequences=True,
    return_state=True
)(encoder_embedding)

# ----------------------------------------------------
# Build Decoder
# ----------------------------------------------------

decoder_inputs = Input(shape=(max_spa_len,))

decoder_embedding = Embedding(
    input_dim=len(spa_tokenizer.word_index) + 1,
    output_dim=embedding_dim
)(decoder_inputs)

decoder_outputs, _, _ = LSTM(
    lstm_units,
    return_sequences=True,
    return_state=True
)(
    decoder_embedding,
    initial_state=[state_h, state_c]
)

# ----------------------------------------------------
# Attention Layer
# ----------------------------------------------------

attention = Attention()(
    [decoder_outputs, encoder_outputs]
)

context = Concatenate()(
    [decoder_outputs, attention]
)

# ----------------------------------------------------
# Output Layer
# ----------------------------------------------------

outputs = Dense(
    len(spa_tokenizer.word_index) + 1,
    activation="softmax"
)(context)

# ----------------------------------------------------
# Build Model
# ----------------------------------------------------

model = Model(
    [encoder_inputs, decoder_inputs],
    outputs
)

# Compile Model
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# ----------------------------------------------------
# Prepare Target Data
# ----------------------------------------------------

decoder_target = np.expand_dims(decoder_output, -1)

# ----------------------------------------------------
# Train Model
# ----------------------------------------------------

history = model.fit(
    [encoder_input, decoder_output],
    decoder_target,
    epochs=50,
    batch_size=2,
    verbose=1
)

# ----------------------------------------------------
# Model Summary
# ----------------------------------------------------

print("\nModel Summary:\n")
model.summary()
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.1000 - loss: 2.1973
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3000 - loss: 2.1889
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3000 - loss: 2.1822
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3000 - loss: 2.1756
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3000 - loss: 2.1682
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3000 - loss: 2.1603
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3000 - loss: 2.1511
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4000 - loss: 2.1405
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4000 - loss: 2.1295
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4000 - loss: 2.1155
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4000 - loss: 2.0972
# Epoch 12/50
# ...

# %% [markdown]
# ### Explanation
#
# 1. A small English–Spanish dataset is created.
# 2. The sentences are tokenized using the Keras **Tokenizer**.
# 3. Both English and Spanish sequences are padded to the same length.
# 4. The **Encoder** uses an Embedding layer followed by an LSTM to encode the English sentence.
# 5. The **Decoder** uses another Embedding layer and LSTM to generate the Spanish translation.
# 6. An **Attention layer** computes the relationship between the encoder outputs and decoder outputs, allowing the decoder to focus on the most relevant words in the input sentence.
# 7. The context vector from the Attention layer is concatenated with the decoder output and passed through a Dense layer with a **Softmax** activation function to predict the translated words.
# 8. The model is trained using the **Adam optimizer** and **Sparse Categorical Crossentropy** loss.

# %% [markdown]
# ###Question 9: Use the following short poetry dataset to simulate poem generation with a pre-trained GPT model:
# ["Roses are red, violets are blue,",
# "Sugar is sweet, and so are you.",
# "The moon glows bright in silent skies,",
# "A bird sings where the soft wind sighs."]
# - Using this dataset as a reference for poetic structure and language, generate a new 2-4
# line poem using a pre-trained GPT model (such as GPT-2). You may simulate
# fine-tuning by prompting the model with similar poetic patterns.

# %%
# Import pipeline
from transformers import pipeline

# Load GPT-2 model
generator = pipeline(
    "text-generation",
    model="gpt2"
)

# Poetry dataset (Reference)
poems = [
    "Roses are red, violets are blue,",
    "Sugar is sweet, and so are you.",
    "The moon glows bright in silent skies,",
    "A bird sings where the soft wind sighs."
]

# Display reference dataset
print("Reference Poetry Dataset:\n")

for line in poems:
    print(line)

# Prompt used for generation
prompt = """
Write a short 2-4 line poem in a similar style.

Roses are red, violets are blue,
Sugar is sweet, and so are you.
The moon glows bright in silent skies,
A bird sings where the soft wind sighs.

Poem:
"""

print("\n" + "="*60)
print("Prompt Used:\n")
print(prompt)

# Generate poem
generated = generator(
    prompt,
    max_new_tokens=40,
    temperature=0.8,
    top_p=0.95,
    do_sample=True
)

# Display generated poem
print("\n" + "="*60)
print("Generated Poem:\n")
print(generated[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'temperature', 'top_p', 'max_new_tokens', 'do_sample'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Reference Poetry Dataset:
#
# Roses are red, violets are blue,
# Sugar is sweet, and so are you.
# The moon glows bright in silent skies,
# A bird sings where the soft wind sighs.
#
# ...
# Prompt Used:
#
#
# Write a short 2-4 line poem in a similar style.
#
# ...

# %% [markdown]
# ### Explanation
#
# 1. The reference poetry dataset is provided to guide the writing style.
# 2. A prompt is created that includes the sample poems and instructs GPT-2 to generate a new 2–4 line poem.
# 3. The GPT-2 model is loaded using the Hugging Face `transformers` library.
# 4. The model generates a new poem based on the provided prompt.
# 5. Parameters such as **temperature** and **top_p** are used to encourage creative and diverse text generation.

# %% [markdown]
# # Question 10: Creative Writing Assistant using Generative AI
#
# ## Problem Statement
#
# A publishing company wants to develop a creative writing assistant that can automatically generate story plots, character descriptions, and creative writing ideas. The system should help writers by providing inspiration while maintaining originality, fairness, and high-quality content.
#
#
# # System Design
#
# The creative writing assistant consists of the following components:
#
# ### 1. User Input
#
# The user provides prompts such as:
#
# - Story genre
# - Theme
# - Character type
# - Writing style
# - Story length
#
# Example:
#
# "Generate a mystery story about a detective."
#
#
#
# ### 2. Data Preprocessing
#
# The training data is cleaned before training the model by:
#
# - Converting text to lowercase
# - Removing unnecessary symbols
# - Tokenization
# - Text normalization
# - Sentence segmentation
#
# This improves the quality of the training data.
#
#
#
# ### 3. Model Selection
#
# A pre-trained **Transformer-based Large Language Model (LLM)** such as **GPT-2** can be used because it is designed for text generation.
#
# The model can be further fine-tuned on:
#
# - Novels
# - Short stories
# - Fairy tales
# - Poetry
# - Movie scripts
#
# to learn different writing styles.
#
#
#
# ### 4. Training Data
#
# The model should be trained on a diverse and high-quality dataset, including:
#
# - Fiction books
# - Public-domain novels
# - Story collections
# - Children's stories
# - Adventure stories
# - Mystery stories
# - Fantasy literature
#
# Using diverse datasets helps the model generate richer and more varied content.
#
#
#
# ### 5. Story Generation
#
# The trained model generates:
#
# - Story titles
# - Story plots
# - Character descriptions
# - Dialogues
# - Story endings
#
# based on the user's prompt.
#
#
# # Bias Mitigation
#
# To ensure fair and responsible content generation:
#
# - Use diverse and balanced training datasets.
# - Remove biased or offensive content from training data.
# - Apply content moderation filters.
# - Regularly evaluate outputs for fairness.
# - Include human review before publishing generated content.
#
#
#
# # Evaluation Methods
#
# The quality of generated content can be evaluated using:
#
# ### Automatic Evaluation
#
# - BLEU Score
# - ROUGE Score
# - Perplexity
# - BERTScore
#
# ### Human Evaluation
#
# - Creativity
# - Grammar
# - Coherence
# - Relevance
# - Originality
# - Readability
#
# Combining automatic and human evaluation provides a more reliable assessment of the generated stories.
#
#
#
# # Real-World Challenges
#
# Developing a creative writing assistant involves several challenges:
#
# - Generating truly original content.
# - Avoiding plagiarism and copyright issues.
# - Preventing biased or offensive outputs.
# - Maintaining logical consistency in long stories.
# - Ensuring factual accuracy when needed.
# - High computational and infrastructure costs.
# - Protecting user privacy and intellectual property.
#
#
#
# # Business Benefits
#
# A Generative AI writing assistant helps publishers by:
#
# - Generating story ideas quickly.
# - Assisting writers in overcoming writer's block.
# - Improving productivity.
# - Creating personalized content.
# - Reducing content creation time.
# - Supporting creative brainstorming.
#
#
#
# # Conclusion
#
# A creative writing assistant built with a **Transformer-based Generative AI model** such as GPT-2 can generate high-quality story plots and character descriptions by learning from large collections of literary works. By combining proper data preprocessing, diverse training data, bias mitigation strategies, and comprehensive evaluation methods, the system can produce creative, engaging, and responsible content while supporting authors and publishers in the writing process.

# %%
from transformers import pipeline

# Load GPT-2 text generation model
generator = pipeline(
    "text-generation",
    model="gpt2"
)

# User prompt
prompt = """
Generate a story plot and a character description.

Genre: Mystery

Theme: Lost Treasure

Character:
"""

# Generate text
result = generator(
    prompt,
    max_new_tokens=150,
    temperature=0.8,
    top_p=0.95,
    do_sample=True
)

# Display prompt
print("User Prompt:\n")
print(prompt)

print("\n" + "="*60)

# Display generated output
print("Generated Story:\n")
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=150) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User Prompt:
#
#
# Generate a story plot and a character description.
#
# Genre: Mystery
#
# Theme: Lost Treasure
#
# Character:
#
#
# ...
# Generated Story:
#
#
# Generate a story plot and a character description.
#
# Genre: Mystery
#
# Theme: Lost Treasure
#
# Character:
#
# Rating: 6/10
#
# Genre: Action
#
# Theme: Horror
#
# Character:
#
# Rating: 6/10
#
# Genre: Adventure
#
# Theme: Thriller
#
# Character:
#
# Rating: 8/10
#
# Genre: Horror
#
# Character:
#
# Rating: 9/10
#
# Genre: Adventure
#
# Genre: Adventure
#
# Genre: Adventure
#
# Genre: Adventure
#
# Genre: Adventure
#
# ...
