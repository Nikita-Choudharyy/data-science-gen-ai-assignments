# %% [markdown]
# #Python OOPs

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
#  - OOPS is a way of programming where we think about things as objects,just like in the real world.
#  Everything around us is a object -a car,moblie,student,etc.
#  Each object has-properties(data),action/behavior(functions).

# %% [markdown]
# 2. What is a class in OOP?
#  - Class is a blueprint for creating object.
#  - For example-Car is class.It have -properties(data)-color,model,speed and behaviours(function)-start,stop,brake.

# %% [markdown]
# 3. What is an object in OOP?
#  - Object is something real made from the class.
#  - it is created from a class and contains-Data,Function.

# %% [markdown]
# 4. What is the difference between abstraction and encapsulation?
#  - INHERITNCE:
#  - When one class(child) derives the properties and methods of another class(parent/base).
#  - Used to create parent-child relationships between classes.
#  - To reuse code and avoid writing the same things again.
#  - ABSTRACTION:
#  - It means showing only the necessary information and hiding the complex internal details from the user.
#  - Used to give a clean and simple interface to the user.
#  - To reduce complexity and show only important details.

# %% [markdown]
# 5. What are dunder methods in Python?
#  - Dunder method also known as magic method and special method. Dunder methods are special predefined methods in Python whose names start and ends with double underscores. They are automatically called by Python to define the behavior of objects,such as initialization,addition,etc.

# %% [markdown]
# 6. Explain the concept of inheritance in OOP?
#  - Inheritance is a concept where one class can use the properties and methods of another class.
#  - For example:

# %%
class human:
  def eat(self):
    print("human can eat")
class vegetarian(human):
  def eat(self,name):
    print(name,"don't consume meat and egg")
class non_vegetarian(human):
  def eat(self,name):
    print(name,"consume meat and egg")
a=vegetarian()
b=non_vegetarian()
a.eat("ram")
b.eat("shyam")
# Out:
# ram don't consume meat and egg
# shyam consume meat and egg

# %% [markdown]
# 7. What is polymorphism in OOP?
#  - Polymorphism means one name, many forms.
#  - Polymorphism is the ability of a single function, method, or operator to perform different tasks depending on the context.

# %% [markdown]
# 8. How is encapsulation achieved in Python?
#  - Encapsulation is the process of hiding data and restricting direct access to it.
#  - Encapsulation achieved in Python by:-public,protected,private method
#  - PUBLIC METHOD:- Accessible from anywhere from outside and inside of class.
#  - PROTECTED METHOD:- Accessible within the class and its subclasses. Indicated by a single underscore(_var).
#  - PRIVATE METHOD:-Accessible only inside the class. Indicated by double underscore(__var).

# %%
class student:
  def __init__(self,name,marks):
    self.name = name     #public
    self._marks = marks  #protected
    self.__grade = 'A'   #private
  #getter for private variable
  def get_grade(self):
    return self.__grade
  #setter for private variable
  def set_grade(self,g):
    self.__grade = g
s=student("ram",90)
print(s.name)         #PUBLIC
print(s._marks)       #PROTECTED
print(s.get_grade())  #PRIVATE
# Out:
# ram
# 90
# A

# %% [markdown]
#  9. What is a constructor in Python?
#   - A constructor is a special function that runs automatically when an object of a class is created.
#   - It is used to set initial values for object attributes and to initialize different attributes for each object.

# %%
class student:
  def __init__(self,name,marks):  # constructor
    self.name = name              # setting object attribute
    self.marks = marks
#constructor runs automatically when object is created
s1=student("ajay",90)

print(s1.name)
print(s1.marks)
# Out:
# ajay
# 90

# %% [markdown]
#  10. What are class and static methods in Python?
#   - CLASS METHOD:-It is a special function that is bound with the class not the object. It can access or modify class variable but cannot instance variable.
#   - It is defined using the @classmethod decorator.The first parameter is cls,which represents the class.

# %%
class student:
  school_name = "VLM"

  @classmethod
  def change_school(cls,name):
    cls.school_name = name

student.change_school("PWSKILLS")
print(student.school_name)
# Out:
# PWSKILLS

# %% [markdown]
#  - STATIC METHOD:-It is a method that does not depend on the class or object.It cannot access instance variables(self) or class variables(cls).It is mostly used as a utility or helper function inside a class.It is an independent function inside a class.
#  - It is defined using the @staticmethod decorator.

# %%
class Math:

  @staticmethod
  def add(a,b):
    return a+b

print(Math.add(7,8))
# Out:
# 15

# %% [markdown]
#  11. What is method overloading in Python?
#   - Method overloading is the ability to create multiple methods with the same name but different parameters in a class.
#   - Python does not support traditional method overloading like others.
#   - If you define multiple methods with the same name,the last method will override the previous one.

# %%
class student():

  def student(self,name=" ",course=" "):   #method with default argument
    print("welcome to PWSKILLS",name,course)

#creating object
stud = student()

#calling method with no argument
stud.student()                      #overloading case 1

#calling method with 1 argument
stud.student("Ajay")                #overloading case 2

#calling method with 2 argument
stud.student("Ajay","datascience")  #overloading case 3
# Out:
# welcome to PWSKILLS
# welcome to PWSKILLS Ajay
# welcome to PWSKILLS Ajay datascience

# %% [markdown]
# 12. What is method overriding in OOP?
#  -  When a child class makes its own version of a method that already exists in the parent class. The child's method replaces(overrides) the parent's method when you call it using the child object.

# %%
class Bank:
  def rate_of_interest(self):
    return "General bank interest is 5%"

class SBI(Bank):
  def rate_of_interest(self):       #method overridding
    return "SBI interest is 6%"

class HDFC(Bank):
  def rate_of_interest(self):       #method overridding
    return "HDFC interest is 7%"

B1=Bank()
S1=SBI()
H1=HDFC()
print(B1.rate_of_interest())
print(S1.rate_of_interest())
print(H1.rate_of_interest())
# Out:
# General bank interest is 5%
# SBI interest is 6%
# HDFC interest is 7%

# %% [markdown]
# 13. What is a property decorator in Python?
#  -  A property decorator in Python allows you to use a method like a normal variable.It help you read or change a value safely without calling the method with parentheses. It is mainly used to control how a class attribute is accessed or updated.
#  - Syntax:- @property

# %%
class student:
  def __init__(self,marks):
    self._marks = marks

  @property             #property decorator
  def marks(self):
    return self._marks

obj = student(90)
print(obj.marks)        #no brackets
# Out:
# 90

# %% [markdown]
# 14. Why is polymorphism important in OOP?
#  -  Polymorphism is important in OOP because it allows the same method name to work differently for different objects. This means we don't need to create separate method names for every class, which makes the code clean and simple. It also gives a lot of flexibility, beacause we can add new classes or change existing ones without affecting the rest of the program.
#  - Another big advantage is that it improves code reusability- one method defined in the parent class can be reused and modified in many child classes. This helps reduce repetition and makes the program easier to manage and understand.Overall, polymorphism makes the whole system more organized, flexble, and easy to maintain.

# %% [markdown]
# 15. What is an abstract class in Python?
#  -  Abstract class is used to hide complex implementation details.Abstract class may contain methods that are just declared and not implemented in abstract class itself. Subclass are responsible for implementing these abstract methods.
#  - Abstract classes are created using the abc module and the @abstractmethod decorator.

# %%
from abc import ABC, abstractmethod

class vehicle(ABC):

  #Abstract method declared but not implemented
  @abstractmethod
  def start(self):
    pass

class car(vehicle):
  def start(self):
    return "car starts with a key"

class bike(vehicle):
  def start(self):
    return "bike starts with a self-start button"

class electricscooter(vehicle):
  def start(self):
    return "electric scooter starts with a power button"

#objects of subclasses
C1 = car()
B1 = bike()
E1 = electricscooter()

print(C1.start())
print(B1.start())
print(E1.start())
# Out:
# car starts with a key
# bike starts with a self-start button
# electric scooter starts with a power button

# %% [markdown]
# 16. What are the advantages of OOP?
#  -  We can reuse the same code in different programs using classes and objects. This saves time and reduces repetition.
#  - OOP breaks a big program into small, manageable parts(called classes). This makes the code easier to understand and organize.
#  - OOP allows us to hide important data and give controlled access. This keeps the data safe and prevents accidental changes.
#  - The same method can work in different ways for differet objects.This makes the code more flexible and easier to extend.
#  - OOP programs are easy to update and fix because code is separated into classes. If one class changes, others are not affected much.
#  - You can create new classes based on old ones. This helps reuse existing code and reduces duplication.
#  - OOP models resl-life things so it becomes easier to design and think about programs.

# %% [markdown]
# 17. What is the difference between a class variable and an instance variable?
#  -  CLASS VARIABLE
#  -  A class variable belongs to the class, not to any specific object.
#  -  All object of that class share the same value.
#  -  It is defined inside the class.
#  -  INSTANCE VARIABLE
#  -  Instance variable belongs to a specific object.
#  -  Every object can have different values for instance variables.
#  -  It is defined inside the conductor or inside methods using self.

# %%
class student:
  school_name = "PW SKILLS"            #class variable(same for all student)
  def __init__(self,name,marks):
    self.name = name                   #instance variable(different for each student)
    self.marks = marks                 #instance variable(different for each student)

#creating objects
S1 = student("ajay",90)
S2 = student("riya",80)

print(S1.name,S1.marks,S1.school_name)
print(S2.name,S2.marks,S2.school_name)
# Out:
# ajay 90 PW SKILLS
# riya 80 PW SKILLS

# %% [markdown]
# 18. What is multiple inheritance in Python?
#  -  In multiple inheritance one child class has two or more parents class.
#  -  This allows the child class to use the properties of all parents class.

# %%
class father:
  def father_skill(self):
    return "Driving"

class mother:
  def mother_skill(self):
    return "Cooking"

class child(father,mother):     #child class inheriting from father and mother
  def child_skill(self):
    return "Studying"

C = child()
print(C.father_skill())    #from father
print(C.mother_skill())    #from mother
print(C.child_skill())     #from child
# Out:
# Driving
# Cooking
# Studying

# %% [markdown]
# 19.  Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.
#
# - In Python, __str__ and __repr__ are special methods used to represent an object as a string.
#
#  - __str__ method:
# The __str__ method is used to return a readable and user-friendly string of an object. It is mainly meant for users. When we use print() on an object, Python calls the __str__ method.
#
#  - __repr__ method:
# The __repr__ method is used to return a detailed and official string representation of an object. It is mainly meant for developers and debugging. It is called when we directly write the object in the Python shell.

# %% [markdown]
# 20. What is the significance of the ‘super()’ function in Python?
#
#   - The super() function in Python is used to access methods and variables of the parent class from a child class.
# It helps in code reuse and avoids writing the parent class name again.
# The super() function is mainly used in inheritance to make the program more clear and organized.

# %% [markdown]
# 21. What is the significance of the __del__ method in Python?
#
#
#  - The `__del__` method in Python is called when an object is destroyed or deleted.
#  - It is used to free resources like memory, files, or database connections used by the object.
# This method helps in proper cleanup before the object is removed from memory.

# %% [markdown]
# 22. What is the difference between @staticmethod and @classmethod in Python?
#  - @staticmethod and @classmethod are used to define methods inside a class, but they work differently.
#
#  - A @staticmethod does not use the object (self) or the class (cls). It behaves like a normal function and is used when the method does not need class data.
#
#  - A @classmethod uses cls as a parameter and can access or modify class variables. It is mainly used when the method works with class-level data.

# %% [markdown]
# 23. What is the difference between @staticmethod and @classmethod in Python?
#
#   - @staticmethod and @classmethod are both used to define methods inside a class.
#
#  - A @staticmethod does not take self or cls as a parameter and cannot access class variables. It is used when the method logic is independent of the class.
#
#  - A @classmethod takes cls as a parameter and can access or modify class variables. It is used when the method needs to work with class-level data.

# %% [markdown]
# 24. What is method chaining in Python OOP?
#
#  - Method chaining in Python OOP means calling more than one method on the same object in a single line.
#  - In method chaining, each method returns the object (`self`) so that another method can be called on it.
#
#  - This concept helps in writing clean and readable code because multiple operations can be performed without creating extra variables.
#  - Method chaining is commonly used in object-oriented programming when methods perform actions and return the same object.
#
# Overall, method chaining makes the program more organized, reduces code length, and improves readability.

# %% [markdown]
# 25. What is the purpose of the __call__ method in Python?
#
#  - The `__call__` method in Python allows an object to be called like a function.
# When the object is called using parentheses `()`, Python automatically executes the `__call__` method.
#
#  - This method is used when we want an object to behave like a function.
# It is helpful in cases where we need to store logic inside an object and reuse it easily.
# Overall, the `__call__` method makes objects more flexible and functional in Python.

# %%
#1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

class Animal:
  def speak(self):
    print("generic message")

class Dog(Animal):
  def speak(self):
    print("Bark!")

d = Dog()
d.speak()
# Out:
# Bark!

# %%
#2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
from abc import ABC, abstractmethod

class Shape(ABC):
  @abstractmethod
  def area(self):
    pass

class circle(Shape):
  def __init__(self,radius):
    self.radius = radius

  def area(self):
    return 3.14 * self.radius * self.radius

class rectangle(Shape):
  def __init__(self,length,width):
    self.length = length
    self.width = width

  def area(self):
    return self.length * self.width

C1 = circle(10)
R1 = rectangle(10,20)
print(C1.area())
print(R1.area())
# Out:
# 314.0
# 200

# %%
#3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

class vehicle:
  def __init__(self,type):
    self.type = type

class car(vehicle):
  def __init__(self,type,brand):
    super().__init__(type)        #calling vehicle construtor
    self.brand = brand

class electriccar(car):
  def __init__(self,type,brand,battery):
    super().__init__(type,brand)         #calling car costrutor
    self.battery = battery

#creating object of electriccar
E1 = electriccar("Four Wheeler","tesla","85 kWh")

print(E1.type)
print(E1.brand)
print(E1.battery)
# Out:
# Four Wheeler
# tesla
# 85 kWh

# %%
#4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.
class Bird:
  def fly(self):
    print("birds can fly")

class Sparrow(Bird):
  def fly(self):
    print("sparrow can fly")

class Penguin(Bird):
  def fly(Bird):
    print("penguin cannot fly")

#function that show polymorphism
def show_flying(Bird):
  Bird.fly()

B1 = Sparrow()
B2 = Penguin()

#calling polymorphism function
show_flying(B1)
show_flying(B2)
# Out:
# sparrow can fly
# penguin cannot fly

# %%
#5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

class BankAccount:
  def __init__(self,balance):
    self.__balance = balance

  def deposit(self,amount):
    self.__balance += amount
    print("Deposit successful.")

  def withdraw(self,amount):
    if self.__balance>=amount:
      self.__balance-=amount

      print("Withdraw successful.")

    else:
      print("Insufficient balance.")

  def get_balance(self):
    return self.__balance

acc1 = BankAccount(2000)
print("Account balance is",acc1.get_balance())
acc1.deposit(500)
print("Account balance is",acc1.get_balance())
acc1.withdraw(1000)
print("Account balance is",acc1.get_balance())
# Out:
# Account balance is 2000
# Deposit successful.
# Account balance is 2500
# Withdraw successful.
# Account balance is 1500

# %%
#6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

class Instrument:
  def play(self):
    print("Music")

class guiter(Instrument):
  def play(self):
    print("Guitar is playing melody")

class piano(Instrument):
  def play(self):
    print("Piano is playing a soft music")

#function to demonstrate runtime polymorphism
def show_playing(Instrument):
  Instrument.play()

#creating object
G1 = guiter()
P1 = piano()

#calling
show_playing(G1)
show_playing(P1)
# Out:
# Guitar is playing melody
# Piano is playing a soft music

# %%
#7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

class Math_Operations:

  @classmethod
  def add_numbers(cls,a,b):
    return a+b

  @staticmethod
  def subtract_number(a,b):
    return a-b

print(Math_Operations.add_numbers(7,20))
print(Math_Operations.subtract_number(50,10))
# Out:
# 27
# 40

# %%
#8. Implement a class Person with a class method to count the total number of persons created.

class person:
  count = 0

  def __init__(self,name):
    self.name = name
    person.count+=1

  @classmethod
  def total_person(cls):
    return cls.count

p1 = person("ajay")
p2 = person("riya")
p3 = person("pooja")
p4 = person("tanvi")
p5 = person("shagun")

print("Total person created",person.total_person())
# Out:
# Total person created 5

# %%
#9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

class Fraction:
  def __init__(self,numerator,denominator):
    self.numerator = numerator
    self.denominator = denominator

  def __str__(self):
    return f"{self.numerator}/{self.denominator}"

print(Fraction(10,20))
# Out:
# 10/20

# %%
""" 10.Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
vectors """



class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y


    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"



v1 = Vector(2, 3)
v2 = Vector(4, 5)


v3 = v1 + v2

print("Resultant Vector:", v3)
# Out:
# Resultant Vector: (6, 8)

# %%
""" 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
{name} and I am {age} years old."""

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")



p1 = Person("Annu", 20)


p1.greet()
# Out:
# Hello, my name is Annu and I am 20 years old.

# %%
""" 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
the average of the grades."""


class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades   # grades should be a list

    def average_grade(self):
        return sum(self.grades) / len(self.grades)


# Creating an object of Student class
s1 = Student("Annu", [80, 85, 90, 75])

# Calculating and printing average grade
print("Average Grade:", s1.average_grade())
# Out:
# Average Grade: 82.5

# %%
"""13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
area"""


class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


# Creating an object of Rectangle class
r1 = Rectangle()

# Setting dimensions
r1.set_dimensions(10, 5)

# Calculating and printing area
print("Area of Rectangle:", r1.area())

# %%
""""14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
and hourly rate. Create a derived class Manager that adds a bonus to the salary."""


class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus


# Creating object of Manager class
m1 = Manager(40, 500, 5000)

# Calculating and printing salary
print("Total Salary:", m1.calculate_salary())
# Out:
# Total Salary: 25000

# %%
"""15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
calculates the total price of the product."""

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity


# Creating an object of Product class
p1 = Product("Laptop", 50000, 2)

# Calculating and printing total price
print("Total Price:", p1.total_price())
# Out:
# Total Price: 100000

# %%
"""16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
implement the sound() method."""


from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass


# Derived class Cow
class Cow(Animal):
    def sound(self):
        print("Cow says Moo")


# Derived class Sheep
class Sheep(Animal):
    def sound(self):
        print("Sheep says Baa")


# Creating objects
c = Cow()
s = Sheep()

# Calling sound methods
c.sound()
s.sound()
# Out:
# Cow says Moo
# Sheep says Baa

# %%
"""17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
returns a formatted string with the book's details."""


class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year: {self.year_published}"


# Creating an object of Book class
b1 = Book("Python Basics", "Guido van Rossum", 2020)

# Getting and printing book information
print(b1.get_book_info())
# Out:
# Title: Python Basics, Author: Guido van Rossum, Year: 2020

# %%
"""18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
attribute number_of_rooms."""

class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price


class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms


# Creating an object of Mansion class
m1 = Mansion("New Delhi", 50000000, 12)

print("Address:", m1.address)
print("Price:", m1.price)
print("Number of Rooms:", m1.number_of_rooms)
# Out:
# Address: New Delhi
# Price: 50000000
# Number of Rooms: 12
